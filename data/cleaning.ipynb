# %%
import pandas as pd

# %%
df_1990_99 = pd.read_csv("1990-99.csv")
df_2000_09 = pd.read_csv("2000-09.csv")
df_2010_14 = pd.read_csv("2010-14.csv")
df_2015_19 = pd.read_csv("2015-19.csv")
df_2020_24 = pd.read_csv("2020-24.csv")

# %%
all_elections = pd.concat([df_1990_99, df_2000_09,df_2010_14,df_2015_19,df_2020_24], ignore_index = True)

# %%
all_elections.drop_duplicates(inplace = True)

# %%
all_elections.to_csv("all_elections.csv")

# %%
all_elections = pd.read_csv("all_elections.csv")

# %%
all_elections
# Out:
#        Unnamed: 0                             Region   Case Number  \
# 0             0.0      Region 02, New York, New York  02-RC-022152
# 1             1.0     Region 32, Oakland, California  32-RC-004664
# 2             2.0     Region 32, Oakland, California  32-RC-004664
# 3             3.0     Region 32, Oakland, California  32-RC-004664
# 4             4.0   Region 14, Saint Louis, Missouri  17-RC-011776
# ...           ...                                ...           ...
# 30335     30411.0       Region 07, Detroit, Michigan  07-RC-253021
# 30336     30412.0        Region 10, Atlanta, Georgia  10-RC-253354
# 30337     30413.0  Region 18, Minneapolis, Minnesota  18-RD-250888
# 30338     30414.0      Region 29, Brooklyn, New York  29-RC-252929
# 30339     30415.0  Region 18, Minneapolis, Minnesota  18-RD-253015
#
#                                                Case Name  Status  Date Filed  \
# 0                             J. J. Cassone Bakery, Inc.  Closed  11/03/1999
# 1      Southern Monterey County Hospital d/b/a George...  Closed  08/13/1999
# 2      Southern Monterey County Hospital d/b/a George...  Closed  08/13/1999
# 3      Southern Monterey County Hospital d/b/a George...  Closed  08/13/1999
# 4      Metro Transport LLC d/b/a Metropolitan Transpo...  Closed  07/26/1999
# ...                                                  ...     ...         ...
# 30335                             Michigan Power Systems  Closed  12/06/2019
# 30336                        Johnston Fire Services, LLC  Closed  12/13/2019
# 30337                              Accentra Credit Union  Closed  10/31/2019
# 30338                   Veolia Energy North America, LLC  Closed  12/06/2019
# 30339                         The Metal Ware Corporation  Closed  12/09/2019
#
#       Date Closed                Reason Closed               City  \
# 0      03/23/2012      Withdrawal Non-adjusted       Port Chester
# 1      02/09/2007      Withdrawal Non-adjusted          King City
# 2      02/09/2007      Withdrawal Non-adjusted          King City
# 3      02/09/2007      Withdrawal Non-adjusted          King City
# 4      10/29/2007  Certific. of Representative        Kansas City
# ...           ...                          ...                ...
# 30335  01/14/2020  Certific. of Representative  Commerce Township
# 30336  06/24/2022      Withdrawal Non-adjusted            Paducah
# 30337  01/10/2020     Certification of Results             Austin
# 30338  01/14/2020  Certific. of Representative             Queens
# 30339  01/09/2020     Certification of Results         Two Rivers
#
#       States & Territories  ... Votes Against Total Ballots Counted  \
# 0                       NY  ...         139.0                 177.0
# 1                       CA  ...          65.0                   8.0
# 2                       CA  ...          65.0                 130.0
# 3                       CA  ...           6.0                   8.0
# 4                       MO  ...          93.0                 186.0
# ...                    ...  ...           ...                   ...
# 30335                   MI  ...           NaN                   5.0
# 30336                   KY  ...           3.0                   5.0
# 30337                   MN  ...           9.0                  16.0
# 30338                   NY  ...           NaN                   NaN
# 30339                   WI  ...           5.0                   8.0
#
#       Runoff Required Challenged Ballots  Challenges are Determinative  \
# 0                   N               21.0                             N
# 1                   N                5.0                             Y
# 2                   N                5.0                             Y
# 3                   N                5.0                             Y
# 4                   N                9.0                             Y
# ...               ...                ...                           ...
# 30335             NaN                1.0                           NaN
# 30336             NaN                1.0                           NaN
# 30337             NaN                NaN                           NaN
# 30338             NaN                NaN                           NaN
# 30339             NaN                1.0                           NaN
#
#                                         Union to Certify  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 30335  Local 58, International Brotherhood of Electri...
# 30336                                                NaN
# 30337                                                NaN
# 30338  International Union of Operating Engineers Loc...
# 30339                                                NaN
#
#                                     Voting Unit (Unit A)  \
# 0      INCLUDED:\t  All full-time and regular part-ti...
# 1      All full-time, regular part-time, and on-call ...
# 2      All full-time, regular part-time, and on-call ...
# 3      All full-time, regular part-time, and on-call ...
# 4      [   All full-time and regular part-time charte...
# ...                                                  ...
# 30335  All full-time and regular part-time electricia...
# 30336  All full-time and regular part-time sprinkler ...
# 30337  All employees of Accentra Credit Union in Aust...
# 30338  Included: All full-time and regular part-time ...
# 30339  All production and maintenance employees, excl...
#
#                                     Voting Unit (Unit B)  \
# 0                                                    NaN
# 1      All full-time, regular part-time, and on-call ...
# 2      All full-time, regular part-time, and on-call ...
# 3      All full-time, regular part-time, and on-call ...
# 4                                                    NaN
# ...                                                  ...
# 30335                                                NaN
# 30336                                                NaN
# 30337                                                NaN
# 30338                                                NaN
# 30339                                                NaN
#
#                                     Voting Unit (Unit C)  \
# 0                                                    NaN
# 1      All full-time, regular part-time, and on-call ...
# 2      All full-time, regular part-time, and on-call ...
# 3      All full-time, regular prt-time, and on-call p...
# 4                                                    NaN
# ...                                                  ...
# 30335                                                NaN
# 30336                                                NaN
# 30337                                                NaN
# 30338                                                NaN
# 30339                                                NaN
#
#                                     Voting Unit (Unit D)
# 0                                                    NaN
# 1      All full-time, regular part-time, and on-call ...
# 2      All full-time, regular part-time, and on-call ...
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 30335                                                NaN
# 30336                                                NaN
# 30337                                                NaN
# 30338                                                NaN
# 30339                                                NaN
#
# [30340 rows x 32 columns]
